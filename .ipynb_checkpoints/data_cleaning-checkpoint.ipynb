# %%
# importing
import pandas as  pd
import numpy as np
import re
import string

# %%
df = pd.read_csv('BA_reviews.csv')
df.head()
# Out:
#    Unnamed: 0                                            reviews  Stars  \
# 0           0  ✅ Trip Verified | British Airways new Club Sui...    5.0
# 1           1  ✅ Trip Verified |  Four very pleasant, on time...    5.0
# 2           2  Not Verified |   We travel extensively over 25...    9.0
# 3           3  ✅ Trip Verified |  Flight delayed an hour due ...    2.0
# 4           4  ✅ Trip Verified |  A very full flight made Pre...    8.0
#
#              date             country
# 0  23rd June 2024           (Canada)
# 1  18th June 2024   (United Kingdom)
# 2  18th June 2024   (United Kingdom)
# 3  17th June 2024   (United Kingdom)
# 4  17th June 2024   (United Kingdom)

# %%
# check the column and rows
df.shape
# Out:
# (7000, 5)

# %%
#  check info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  7000 non-null   int64
#  1   reviews     7000 non-null   object
#  2   Stars       6996 non-null   float64
#  3   date        7000 non-null   object
#  4   country     6998 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 273.6+ KB

# %%
# check the missed value
df.isnull().sum().max()
# Out:
# 4

# %%
# handle missed country data by drop 
df = df.dropna()
df.isnull().sum()
# Out:
# Unnamed: 0    0
# reviews       0
# Stars         0
# date          0
# country       0
# dtype: int64

# %%
# delete unnamed column
df = df.drop(columns = ['Unnamed: 0'])
# to check the df
df.head()
# Out:
#                                              reviews  Stars            date  \
# 0  ✅ Trip Verified | British Airways new Club Sui...    5.0  23rd June 2024
# 1  ✅ Trip Verified |  Four very pleasant, on time...    5.0  18th June 2024
# 2  Not Verified |   We travel extensively over 25...    9.0  18th June 2024
# 3  ✅ Trip Verified |  Flight delayed an hour due ...    2.0  17th June 2024
# 4  ✅ Trip Verified |  A very full flight made Pre...    8.0  17th June 2024
#
#               country
# 0           (Canada)
# 1   (United Kingdom)
# 2   (United Kingdom)
# 3   (United Kingdom)
# 4   (United Kingdom)

# %%
# extract the column of verified
df['Verified'] = df['reviews'].str.contains('Trip Verified')

# %%
df['country']
# Out:
# 0                (Canada)
# 1        (United Kingdom)
# 2        (United Kingdom)
# 3        (United Kingdom)
# 4        (United Kingdom)
#                ...
# 6995         United States
# 6996             Australia
# 6997        United Kingdom
# 6998        United Kingdom
# 6999        United Kingdom
# Name: country, Length: 6994, dtype: object

# %%
df['Stars'].unique()
# Out:
# array([ 5.,  9.,  2.,  8.,  7.,  1.,  3.,  4.,  6., 10.])

# %%
# remove the bracket in country column
df['country'] = df['country'].str.replace('(','')
df['country'] = df['country'].str.replace(')','')

# %%
df.head()
# Out:
#                                              reviews  Stars            date  \
# 0  ✅ Trip Verified | British Airways new Club Sui...    5.0  23rd June 2024
# 1  ✅ Trip Verified |  Four very pleasant, on time...    5.0  18th June 2024
# 2  Not Verified |   We travel extensively over 25...    9.0  18th June 2024
# 3  ✅ Trip Verified |  Flight delayed an hour due ...    2.0  17th June 2024
# 4  ✅ Trip Verified |  A very full flight made Pre...    8.0  17th June 2024
#
#             country  Verified
# 0           Canada       True
# 1   United Kingdom       True
# 2   United Kingdom      False
# 3   United Kingdom       True
# 4   United Kingdom       True

# %% [markdown]
# ##### Cleaning reviews

# %%
df['reviews']
# Out:
# 0       ✅ Trip Verified | British Airways new Club Sui...
# 1       ✅ Trip Verified |  Four very pleasant, on time...
# 2       Not Verified |   We travel extensively over 25...
# 3       ✅ Trip Verified |  Flight delayed an hour due ...
# 4       ✅ Trip Verified |  A very full flight made Pre...
#                               ...
# 6995    Just took British from London to Seattle. Tire...
# 6996    Travelled from SYD to London return. Poor serv...
# 6997    VIE to LHR - Seats were of the new configurati...
# 6998    LGW to SZG. Absolutely useless for a scheduled...
# 6999    BA92 4/10/14 YYZ-LHR B787 G-ZBJE. If you want ...
# Name: reviews, Length: 6994, dtype: object

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def clean_text(text):
    # Remove "✅ Trip Verified", "Not Verified" and "|"
    text = text.replace('✅ Trip Verified', '')
    text = text.replace('Not Verified', '')
    text = text.replace('|', '')
    
    # Remove punctuation and digits
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\d+', '', text)      # Remove digits
    
    # Tokenize the text
    words = text.split()
    
    # Initialize the lemmatizer
    lemmatizer = WordNetLemmatizer()
    
    # Remove stopwords and lemmatize the words
    cleaned_text = ' '.join(lemmatizer.lemmatize(word.lower()) for word in words if word.lower() not in stopwords.words('english'))
    
    return cleaned_text.strip()

# %%
df['cleaned_reviews'] = df['reviews'].apply(clean_text)
df['cleaned_reviews']
# Out:
# 0       british airway new club suite marked improveme...
# 1       four pleasant time flight friendly helpful sta...
# 2       travel extensively year tend use ba regular tr...
# 3       flight delayed hour due bad weather around jfk...
# 4       full flight made premium economy feel little l...
#                               ...
# 6995    took british london seattle tired airplane fle...
# 6996    travelled syd london return poor service board...
# 6997    vie lhr seat new configuration inch club econo...
# 6998    lgw szg absolutely useless scheduled service w...
# 6999    ba yyzlhr b gzbje want know ryanair long haul ...
# Name: cleaned_reviews, Length: 6994, dtype: object

# %%
df['date'].head()
# Out:
# 0    23rd June 2024
# 1    18th June 2024
# 2    18th June 2024
# 3    17th June 2024
# 4    17th June 2024
# Name: date, dtype: object

# %% [markdown]
# ##### clean of dates

# %%
# chnaging the date format
# Function to remove ordinal suffixes
def remove_ordinal_suffix(date_str):
    return re.sub(r'(\d+)(st|nd|rd|th)', r'\1', date_str)

# Apply the function to the 'date' column
df['date'] = df['date'].apply(remove_ordinal_suffix)

# Convert the cleaned date strings to datetime objects
df['date'] = pd.to_datetime(df['date'], format='%d %B %Y')

# Display the resulting dataframe
df['date'].head()
# Out:
# 0   2024-06-23
# 1   2024-06-18
# 2   2024-06-18
# 3   2024-06-17
# 4   2024-06-17
# Name: date, dtype: datetime64[ns]

# %%
# check of stars
df['Stars'].value_counts()
# Out:
# Stars
# 1.0     1727
# 2.0      812
# 3.0      812
# 8.0      676
# 10.0     563
# 7.0      549
# 9.0      545
# 5.0      492
# 4.0      468
# 6.0      350
# Name: count, dtype: int64

# %%
# change dtype into integer
df['Stars'] = df['Stars'].astype('int64')
# check the column info
df['Stars'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6994 entries, 0 to 6999
# Series name: Stars
# Non-Null Count  Dtype
# --------------  -----
# 6994 non-null   int64
# dtypes: int64(1)
# memory usage: 109.3 KB

# %%
df['Stars'].unique()
# Out:
# array([ 5,  9,  2,  8,  7,  1,  3,  4,  6, 10], dtype=int64)

# %%
# display cleaned data
df.head()
# Out:
#                                              reviews  Stars       date  \
# 0  ✅ Trip Verified | British Airways new Club Sui...      5 2024-06-23
# 1  ✅ Trip Verified |  Four very pleasant, on time...      5 2024-06-18
# 2  Not Verified |   We travel extensively over 25...      9 2024-06-18
# 3  ✅ Trip Verified |  Flight delayed an hour due ...      2 2024-06-17
# 4  ✅ Trip Verified |  A very full flight made Pre...      8 2024-06-17
#
#             country  Verified  \
# 0           Canada       True
# 1   United Kingdom       True
# 2   United Kingdom      False
# 3   United Kingdom       True
# 4   United Kingdom       True
#
#                                      cleaned_reviews
# 0  british airway new club suite marked improveme...
# 1  four pleasant time flight friendly helpful sta...
# 2  travel extensively year tend use ba regular tr...
# 3  flight delayed hour due bad weather around jfk...
# 4  full flight made premium economy feel little l...

# %% [markdown]
# ### EDA

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS

# %%
# Join all reviews into a single string
text = ' '.join(df['cleaned_reviews'])

# Set up stopwords
stopwords = set(STOPWORDS)
stopwords.update(['BA', 'flight', 'british','Airway','London','aircraft','one'])

# Generate the word cloud
wd = WordCloud(height=400, width=400, max_font_size=300, background_color='white', stopwords=stopwords).generate(text)

# Display the word cloud
plt.figure(figsize=(17, 12))
plt.imshow(wd, interpolation='bilinear')
plt.axis('off')  # Hide the axis
plt.show()

# %%
# Join all reviews into a single string
text = ' '.join(df['cleaned_reviews'])

# Set up stopwords
stopwords = set(STOPWORDS)
stopwords.update(['BA', 'flight', 'british','Airway','London','aircraft','one','airport','plane'])

# Generate the word cloud
wd = WordCloud(height=400, width=400, max_font_size=300, background_color='white', stopwords=stopwords).generate(text)

# Display the word cloud
plt.figure(figsize=(17, 12))
plt.imshow(wd, interpolation='bilinear')
plt.axis('off')  # Hide the axis
plt.show()

# %% [markdown]
# ##### Word Frequency

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import ngrams

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer


# Define the ngram range (1, 1) for unigrams, (2, 2) for bigrams, and (3, 3) for trigrams
ngram_range = (3, 3)  

# Create an instance of CountVectorizer
vectorizer = CountVectorizer(ngram_range=ngram_range)

# Fit and transform the text data
X = vectorizer.fit_transform(df['cleaned_reviews'])

# Convert the result to a DataFrame for better visualization
ngram_frequencies = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())

# Sum the frequencies of each ngram across all documents
ngram_frequencies = ngram_frequencies.sum().reset_index()
ngram_frequencies.columns = ['ngram', 'frequency']
ngram_frequencies = ngram_frequencies.sort_values(by='frequency', ascending=False)

# Display the ngram frequencies
ngram_frequencies
# Out:
#                               ngram  frequency
# 251821       verified review london        368
# 199627       review london heathrow        224
# 37295           business class seat        202
# 35355         british airway flight        195
# 94643           flew british airway        191
# ...                             ...        ...
# 55168   competitor route thoroughly          1
# 83954         even though expensive          1
# 249408           upon flight phoned          1
# 55186            complain ba amazed          1
# 232039              take much space          1
#
# [265177 rows x 2 columns]

# %%
w
